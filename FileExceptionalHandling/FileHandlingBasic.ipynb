# %%
# mode
# r >> read mode
# w>> write mode
# a>> append mode
# r+>> both reading and writing

# %%
open("files.txt",'r') # if there is no any file, and you open it in read mode it will throw an error
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 open("files.txt",'r') # if there is no any file, and you open it in read mode it will throw an error
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'files.txt'

# %%
file=open("file.txt","w") #w>>write mode,if a file is not there it will create the file.txt and then read it.
# Out:
# <_io.TextIOWrapper name='file.txt' mode='w' encoding='cp1252'>

# %%
file=open("file.txt","w")
file.write("Hello this is my first line in the text file") # number below is no of bytes you have written.
# Out:
# 44

# %%
# as of now if you open the written file you will not able to see any text to file
# to see you have to close the file

# %%
file.close() # if file is closed it will return true

# %%
file # file attribute
# Out:
# <_io.TextIOWrapper name='file.txt' mode='w' encoding='cp1252'>

# %%
file.closed # to check file is closed or not
# Out:
# True

# %%
file=open("file.txt","r")
file.closed()

# %%
file.name
# Out:
# 'file.txt'

# %%
file.mode
# Out:
# 'r'

# %%
file.write("This is my second line") # this will not be executed,throw an error>>file is closed you can not write anything.
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 file.write("This is my second line") # this will not be executed,throw an error>>file is closed you can not write anything.
#
# UnsupportedOperation: not writable

# %%
file=open("file.txt","w") # it will truncate(delete) all earlier content and make a fresh file.txt

# %%
file.close
# Out:
# <function TextIOWrapper.close()>

# %%
file=open("file.txt","w")
file.write("This is fifth line") # all earlier content will deleted
file.close()

# %%
file=open("file.txt","w")
file.write("This is my first line \n")
file.write("This is my second line \n")
file.write("This is my third line \n")
file.write("this is my fourth line \n")
file.close()

# %%
file=open("file.txt","a")
file.write("This is fifth line")
file.close()

# %%
for i in file:
    print(i)

# %%
file=open("file.txt","w")
file.write("Hello ,I am a Smriti Mandhana \n")
file.write("Hello,I am a Pratika Rawat \n")
file.write("Hello,I am a shafali Verma \n")
file.write("Hello,I am a Harmanpeet Kaur \n")
file.write("Hello,I am a Richa Ghosh \n")
file.close()

# %%
file=open("file.txt","a")
file.write("Hello I am Radha Yadav")
file.close()

# %%
file=open("file.txt","r")

# %%
file.write("This is a another file")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 file.write("This is a another file")
#
# UnsupportedOperation: not writable

# %%
file
# Out:
# <_io.TextIOWrapper name='file.txt' mode='r' encoding='cp1252'>

# %%
for i in file:
    print(i)
# Out:
# Hello ,I am a Smriti Mandhana
#
# Hello,I am a Pratika Rawat
#
# Hello,I am a shafali Verma
#
# Hello,I am a Harmanpeet Kaur
#
# Hello,I am a Richa Ghosh
#
# Hello I am Radha Yadav

# %%
file.read
# Out:
# <function TextIOWrapper.read(size=-1, /)>

# %%
print(file.read()) # here the cursor/pointer is at last position

# %%
file.read()
# Out:
# ''

# %%
file.tell() # it tells the current position of the cursor
# Out:
# 170

# %%
file.seek(0)
# Out:
# 0

# %%
f=open("file.txt","r")
f.seek(0) # it will bring cursor to start of the file
print(f.read()) # it will read everything from starting
f.close()
# Out:
# Hello ,I am a Smriti Mandhana
# Hello,I am a Pratika Rawat
# Hello,I am a shafali Verma
# Hello,I am a Harmanpeet Kaur
# Hello,I am a Richa Ghosh
# Hello I am Radha Yadav

# %%
f=open("file.txt","r")
print(f.readline()) # it will only read the first line
f.close()
# Out:
# Hello ,I am a Smriti Mandhana

# %%
f=open("file.txt","r")
print(f.readlines()) # all the lines will be element of a list
f.close()
# Out:
# ['Hello ,I am a Smriti Mandhana \n', 'Hello,I am a Pratika Rawat \n', 'Hello,I am a shafali Verma \n', 'Hello,I am a Harmanpeet Kaur \n', 'Hello,I am a Richa Ghosh \n', 'Hello I am Radha Yadav']

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\91921\\OneDrive\\Desktop\\Python\\function\\FileExceptionalHandlingAndMemoryManagement'

# %%
os.path.getsize("file.txt")
# Out:
# 170

# %%
os.mkdir("test")

# %%
os.mkdir("test/test1")

# %%
os.makedirs("1/2/3/4")

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 602E-AE5A
#
#  Directory of c:\Users\91921\OneDrive\Desktop\Python\function\FileExceptionalHandlingAndMemoryManagement
#
# 11/05/2025  10:34 AM    <DIR>          .
# 11/04/2025  09:42 PM    <DIR>          ..
# 11/05/2025  10:34 AM    <DIR>          1
# 11/05/2025  10:06 AM               170 file.txt
# 11/05/2025  10:34 AM            17,104 FileHandlingBasic.ipynb
# 11/05/2025  10:33 AM    <DIR>          test
#                2 File(s)         17,274 bytes
#                4 Dir(s)  319,555,379,200 bytes free

# %%
os.listdir()
# Out:
# ['1', 'file.txt', 'FileHandlingBasic.ipynb', 'test']

# %%
os.mkdir("feat")

# %%
os.rmdir("feat") # to delete one directory without any content inside the directory

# %%
import shrutil
shrutil.rmtree("test")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 import shrutil
#       2 shrutil.rmtree("test")
#
# ModuleNotFoundError: No module named 'shrutil'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\91921\\OneDrive\\Desktop\\Python\\function\\FileExceptionalHandlingAndMemoryManagement'

# %%
os.makedirs("test/test1")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 os.makedirs("test/test1")
#
# File <frozen os>:227, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'test/test1'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
