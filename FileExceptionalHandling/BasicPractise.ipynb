# %%
file=open("file1.txt","w")
file.write("This is a my first file /n")
file.write("This is my second file/n")
file.close()

# %%
file=open("file1.txt","w")
file.write("Hello ! whtsapp /n")
file.write("Good /n")
file.close()

# %%
nikhil=open("file.txt","r")

# %%
f=open("file.txt","w")
f.write("Hello ,I am a Nikhil Yadav \n")
f.write("Hello,I am a Devender Singh \n")
f.write("Hello,I am a Mohit Verma \n")
f.write("Hello , I am a Aditya Raj Jaiswal \n")
f.write("Hello,I am a Deveshwar Pandey \n")
f.close()

# %%
nikhil=open("file.txt","r")

# %%
for i in nikhil:
    print(i)
# Out:
# Hello ,I am a Nikhil Yadav
#
# Hello,I am a Devender Singh
#
# Hello,I am a Mohit Verma
#
# Hello , I am a Aditya Raj Jaiswal
#
# Hello,I am a Deveshwar Pandey

# %%
file=open("file.txt","r")

# %%
for i in file:
    print(i)
# Out:
# Hello ,I am a Nikhil Yadav
#
# Hello,I am a Devender Singh
#
# Hello,I am a Mohit Verma
#
# Hello , I am a Aditya Raj Jaiswal
#
# Hello,I am a Deveshwar Pandey

# %%
f=open("file.txt","r")
print(f.readline())
f.close()
# Out:
# Hello ,I am a Nikhil Yadav

# %%
print(file.read())

# %%
f=open("file.txt","r")
print(f.readlines())
f.close()
# Out:
# ['Hello ,I am a Nikhil Yadav \n', 'Hello,I am a Devender Singh \n', 'Hello,I am a Mohit Verma \n', 'Hello , I am a Aditya Raj Jaiswal \n', 'Hello,I am a Deveshwar Pandey \n']

# %%
f=open("file.txt","r")
print(f.read())
f.close()
# Out:
# Hello ,I am a Nikhil Yadav
# Hello,I am a Devender Singh
# Hello,I am a Mohit Verma
# Hello , I am a Aditya Raj Jaiswal
# Hello,I am a Deveshwar Pandey

# %%
dividend=int(input("Enter Dividend:"))
divisior=int(input("Enter Divisior:"))
quotient=dividend // divisior
remainder=dividend % divisior
print(f"When {dividend} is divided by {divisior},the quotient is {quotient}.")
print(f"When {dividend} is divided by {divisior} the remainder is {remainder}")
# Out:
# When 9 is divided by 2,the quotient is 4.
# When 9 is divided by 2 the remainder is 1

# %%
divident=int(input("Enter Dividend:"))
divisior=int(input("Enter Divisior:"))
quotient=divident // divisior
remainder=dividend % divisior
print(f"When {dividend} is divided by {divisior},the quotient is {quotient}")
print(f"When {dividend} is divided by {divisior},the quotient is {remainder}")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 divident=int(input("Enter Dividend:"))
#       2 divisior=int(input("Enter Divisior:"))
# ----> 3 quotient=divident // divisior
#       4 remainder=dividend % divisior
#       5 print(f"When {dividend} is divided by {divisior},the quotient is {quotient}")
#
# ZeroDivisionError: integer division or modulo by zero

# %%
divident=int(input("Enter Dividend:"))
divisior=int(input("Enter Divisior:"))
quotient=divident // divisior
remainder=dividend % divisior
print(f"When {dividend} is divided by {divisior},the quotient is {quotient}")
print(f"When {dividend} is divided by {divisior},the quotient is {remainder}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 divident=int(input("Enter Dividend:"))
# ----> 2 divisior=int(input("Enter Divisior:"))
#       3 quotient=divident // divisior
#       4 remainder=dividend % divisior
#
# ValueError: invalid literal for int() with base 10: 'Darshan'

# %%
divident=int(input("Enter Dividend:"))
divisior=int(input("Enter Divisior:"))
quotient=divident // divisior
remainder=dividend % divisior
print(f"When {dividend} is divided by {divisior},the quotient is {quotient}")
print(f"When {dividend} is divided by {divisior},the quotient is {remainder}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 divident=int(input("Enter Dividend:"))
#       2 divisior=int(input("Enter Divisior:"))
#       3 quotient=divident // divisior
#
# ValueError: invalid literal for int() with base 10: 'Darshan'

# %%
try:
    dividend=int(input("Enter Dividend:"))
    divisior=int(input("Enter Divisior"))
    quotient=dividend // divisior
    remainder=dividend % divisior
except Exception:
    print("Something is wrong.Please try again.")
else:
    print(f"When {dividend} is divided by {divisior},the quotient is {quotient}")
    print(f"When {dividend} is divided by {divisior},the remainder is {remainder}")
# Out:
# When 9 is divided by 2,the quotient is 4
# When 9 is divided by 2,the remainder is 1

# %%
try:
    dividend=int(input("Enter Dividend:"))
    divisior=int(input("Enter Divisior:"))
    quotient=dividend // divisior
    remainder=dividend % divisior
except Exception:
    print("Something is wrong.Please Try again")
else:
    print(f"When {dividend} is divided by {divisior},the quotient is {quotient}")
    print(f"When {dividend} is divided by {divisior},the remainder is {remainder}")
# Out:
# Something is wrong.Please Try again

# %%
try:
    dividend=int(input("Enter Dividend:"))
    divisior=int(input("Enter Divisior:"))
    quotient=dividend // divisior
    remainder=dividend % divisior
except ZeroDivisionError:
    print("Division by zero is not allowed.Please provide a non-zero error")
    print(f"When {dividend} is divided by {divisior},the remainder is {remainder}")
# Out:
# Division by zero is not allowed.Please provide a non-zero error
# When 9 is divided by 0,the remainder is 1

# %%
try:
    dividend=int(input("Enter Dividend:"))
    divisior=int(input("Enter Divisior:"))
    quotient=dividend // divisior
    remainder=dividend % divisior
except ZeroDivisionError:
    print("Divisior by zero is not allowed.please provide a non-zero divisior")
except ValueError:
    print("Invalid input.Please enter numeric values for dividend and divisior.")
else:
    print(f"When {dividend} is divided by {divisior},the quotient is {quotient}")
    print(f"When {dividend} is divided by {divisior},the remainder is {remainder}")
# Out:
# Invalid input.Please enter numeric values for dividend and divisior.

# %%
try:
    dividend=int(input("Enter Dividend:"))
    divisior=int(input("Enter Divisior:"))
    quotient=dividend // divisior
    remainder=dividend % divisior
except ZeroDivisionError:
    print("Division by zero is not allowed.Please provide a non-zero divisior.")
except ValueError:
    print("Invalid input.Please enter numeric value for dividend and divisior.")
except Exception:
    print("An unexpected error occurred.Please try again.")
else:
    print(f"When {dividend} is divided by {divisior},the quotient is {quotient}")
    print(f"When {dividend} is divided by {divisior},the remainder is {remainder}.")
# Out:
# Invalid input.Please enter numeric value for dividend and divisior.

# %%
try:
    dividend=int(input("Enter Dividend:"))
    divisior=int(input("Enter Divisior:"))
    quotient=dividend // divisior
    remainder=dividend % divisior
except ZeroDivisionError as zde:
    print(f"Division by zero is not allowed.Please provide a non-zero divisior.Error details:{zde}")
except ValueError as ve:
    print(f"Invalid input.Please enter numeric values for dividend and divisior.Error details:{ve}")
except Exception as e:
    print(f"An unexpected error occured.Please try again.Error details:{e}")
else:
    print(f"When {dividend} is divided by {divisior},the quotient is {quotient}")
    print(f"When {dividend} is divided by {divisior},the remainder is {remainder}")
# Out:
# Invalid input.Please enter numeric values for dividend and divisior.Error details:invalid literal for int() with base 10: 'nikhil'

# %%
my_list=[1,2,3]
my_iter=iter(my_list)

print(next(my_iter))
print(next(my_iter))
print(next(my_iter))

try:
    print(next(my_iter))
except StopIteration as si:
    print(f"StopIteration exception caught:{si}")
# Out:
# 1
# 2
# 3
# StopIteration exception caught:

# %%
try:
    dividend=int(input("Enter dividend:"))
    divisior=int(input("Enter divisior:"))
    quotient=dividend // divisior
    remainder=dividend // divisior
except(ZeroDivisionError,ValueError) as e:
    print(f"An error occured dur to:{e}")
else:
    print(f"when {dividend} is divided by {divisior},the quitient is {quotient}")
    print(f"When {dividend} is divided by {divisior} the remainder is {remainder}")
# Out:
# An error occured dur to:invalid literal for int() with base 10: 'nikhil'

# %%
try:
    dividend=int(input("Enter Dividend:"))
    divisior=int(input("Enter divisior:"))
    quotient=dividend // divisior
    remainder=dividend % divisior
except ZeroDivisionError as zde:
    print(f"Division by zero is not allowed.Please provide a non-zero division.Error details:{zde}")
except ValueError as ve:
    print(f"Invalid input.Please enter numeric values for dividend and divisior.Error details:{ve}")
except Exception as e:
    print(f"An unexcepted error occured.Please try again.Error details:{e}")
else:
    print(f"When {dividend} is divided by {divisior},the quotient is {quotient}")
    print(f"When {dividend} is divided by {divisior},the remainder is {remainder}")
finally:
    print("I am executed no matter what!")
# Out:
# Invalid input.Please enter numeric values for dividend and divisior.Error details:invalid literal for int() with base 10: '9 darshan'
# I am executed no matter what!

# %%
try:
    file=open("sample.txt","r")
    content=file.read()
    print(content)
except FileNotFoundError as fnfe:
    print(f"FileNotFoundError exception caught:{fnfe}")
finally:
    try:
        file.close()
    except NameError:
        pass
    print("File has been closed")
# Out:
# FileNotFoundError exception caught:[Errno 2] No such file or directory: 'sample.txt'
# File has been closed

# %%
class BankAccount:
    def __init__(self,balance):
        self.__balance=balance

    def withdraw(self,amount):
        try:
            if amount>self.__balance:
                raise ValueError("Insufficient funds for withdrawl.")
            self.__balance-=amount
            print(f"Withdrawl of {amount} successful.New Balance:{self.__balance}")
        except ValueError as ve:
            print(f"ValueError exception caught:{ve}")

account=BankAccount(1000)
account.withdraw(500)
account.withdraw(600)
# Out:
# Withdrawl of 500 successful.New Balance:500
# ValueError exception caught:Insufficient funds for withdrawl.
