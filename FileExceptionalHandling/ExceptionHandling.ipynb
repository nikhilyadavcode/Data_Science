# %%
# generally something that disrups the normal event is exception
# In python an exception is an event that occurs during programme execution that disrupts the regular flow of code

# %%
5/9
# Out:
# 0.5555555555555556

# %%
10/2
# Out:
# 5.0

# %%
print(4/2)
print(3/5)
print("The code is running fine till now")
print(6/0) # this is suspicious code
print("You name is Ajay")
print(2+3)
print("The code ends")
# Out:
# 2.0
# 0.6
# The code is running fine till now
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 print(3/5)
#       3 print("The code is running fine till now")
# ----> 4 print(6/0)
#       5 print("You name is Ajay")
#       6 print(2+3)
#
# ZeroDivisionError: division by zero

# %%
print("this is my first line of code")
print(3*5*6)
d={"name":"Ajay"}
print(type(d))
print(d["age"]) # it throws an error why code after this didn't got executed
print("This is last line of code")
# Out:
# this is my first line of code
# 90
# <class 'dict'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 5
#       3 d={"name":"Ajay"}
#       4 print(type(d))
# ----> 5 print(d["age"])
#       6 print("This is last line of code")
#
# KeyError: 'age'

# %%
f=open("hello.txt","r")
print(6+3)
print("The file is opened and now i am performing some steps")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 f=open("hello.txt","r")
#       2 print(6+3)
#       3 print("The file is opened and now i am performing some steps")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hello.txt'

# %%
# you were excepting something but it didn't happen due to which the suspicious line throw error and
# the next line of code didn't got executed.
#ZeroDivisionError,typeerror,filenotfounderror >> these are exception rising due to suspicious code
# otherexceptions>>import error,runtime error

# why we do need to handle suspicious code/exceptions?
# --Robust Application
# -- code cleaner>> fellow developer understands the corner cases

# how to handle exception
# >> using try catch block to handle exceptions
# >> whenever exception occurs >> python stops len program and generate exception
# >> handling this exception is advised
# every code that is risky/suspicious you should do exception handling

# %%
# syntax of try except
#try:
    #suspicious code
#except:
    # executed when exception occurs in try block
try:
   f=open("nikhil.txt","r")
except Exception as e:
     print("there is an issue with the code and the issue is:",e)
print(6+3)
print("The file is opened and now I am performing some steps")
# Out:
# there is an issue with the code and the issue is: [Errno 2] No such file or directory: 'nikhil.txt'
# 9
# The file is opened and now I am performing some steps

# %%
try:
    5/0
except Exception as e:
    print(e)
print(5+3)
print("Your name is Ajay")
print(2+3)
print("The code ends")
# Out:
# division by zero
# 8
# Your name is Ajay
# 5
# The code ends

# %%
try:
    f=open("Nikhil.txt","r")
except Exception as e:
    print("There is an issues with the code and the issue is:",e)
else:
    print("This will be executed if try except block is executed without any exception")
print(5+3)
# Out:
# There is an issues with the code and the issue is: [Errno 2] No such file or directory: 'Nikhil.txt'
# 8

# %%
# use case of else>> you want to execute some code if the try statement 
# is successful and code doen't enter into exception of block.

# %%
# use case 1
try:
    f=open("example1.txt","w")
except Exception as e:
    print("There is an issues with the code and the issues is:",e)
else:
    print(5+3)
    print("This will be executed if try except block is executed without any exception.")
# Out:
# 8
# This will be executed if try except block is executed without any exception.

# %%
# use case 2

try:
    f=open("example1.txt","w")
    f.write("Hello to exception handling") 
# you will not be able to see written content untill you close the file, close the file in else block.
except Exception as e:
    print("There is an issue with the code and the issue is:",e)
else:
    print(5+3)
    print("There will be executed if try except block is executed without any exception.")
# Out:
# 8
# There will be executed if try except block is executed without any exception.

# %%
try:
    f=open("example1.txt","w")
    f.write("Hello to exception handling")
except Exception as e:
    print("There is an issue with the code and the issue is:",e)
else:
    f.close()
    print(5+3)
    print("This will be executed if try except block is executed without any exception.")
# Out:
# 8
# This will be executed if try except block is executed without any exception.

# %%
# else block is very helpful when your code didn't enter the exception block
# for example you wanted to close the file after it was opened in try block

# %%
# finally block >>always executed
# even if you enter exception block or not,finally will be executed always
# similar to other lines of code
try:
    f=open("example1.txt",'w')
    f.write("Hello to exception handling")
except Exception as e:
    print("There is an issue with the code and the issue is:",e)
else:
    f.close()
    print(5+3)
    print("This will be executed if try except block is executed without any exception.")
finally:
    print("This will be executed always")
# Out:
# 8
# This will be executed if try except block is executed without any exception.
# This will be executed always

# %%
# another example
try:
    5/0
except Exception as e:
    print(e)
finally:
    print("This will be printed always")
# Out:
# division by zero
# This will be printed always

# %%
# custom exception
income=int(input('Enter your salary'))

# %%
def validate_salary(salary):
    if salary <=0:
        print("Negative salary is not possible")
    elif salary>=3000000:
        print("salary is unexcepted ")
    else:
        print("salary is valid")

validate_salary(500)
# Out:
# salary is valid

# %%
# custom exception class
class ValidateSalary(Exception): # Exception is the parent class where all the type of python exceptions are 
    def __init__(self,message):
        self.message=message

# %%
class ValidateSalary(Exception):
    pass

def validate_salary(salary):
    if salary <= 0:
        raise ValidateSalary("Negative salary is not possible")
    elif salary >= 3000000:
        raise ValidateSalary("Salary is unexpected")
    else:
        print("Salary is valid")

try:
    salary = int(input("Enter your salary: "))
    validate_salary(salary)
except ValidateSalary as e:
    print(e)
# Out:
# Negative salary is not possible
