# %%
def chatbot():
    print("Hello! I’m ChatBuddy. Type 'bye' to exit.\n")

    while True:
        user_input = input("You: ").lower()  # convert input to lowercase

        if user_input == "hello" or user_input == "hi":
            print("ChatBuddy: Hello! How are you?")
        elif "how are you" in user_input:
            print("ChatBuddy: I'm just a program, but I'm doing great! 😄")
        elif "your name" in user_input:
            print("ChatBuddy: My name is ChatBuddy, your Python friend!")
        elif "weather" in user_input:
            print("ChatBuddy: I can’t check live weather yet, but I hope it’s sunny! ☀️")
        elif "bye" in user_input:
            print("ChatBuddy: Goodbye! Have a great day! 👋")
            break
        else:
            print("ChatBuddy: Sorry, I didn’t understand that. 🤔")

chatbot()
# Out:
# Hello! I’m ChatBuddy. Type 'bye' to exit.
#
# ChatBuddy: Goodbye! Have a great day! 👋
